# %% [markdown]
# <a href="https://colab.research.google.com/github/beryl09/beryl09/blob/main/PS0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **My Analysis**
#
# I would like to research on the invasive cancer incidence rates in all site in the New Jersey counties with respect to specific age rates and 5 year profile

# %% [markdown]
# **Resources**
#
# I obtained population data for cancer registry from: http://seer.cancer.gov/popdata/
#
# The geographical NJ shapefile can be downloaded from:Cancer-Rates.info/NJ

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#! pip install geopandas
#!pip install mapclassify
import geopandas as gpd
#import mapclassify

# %% [markdown]
# ## Mapping the NJ Sate

# %%
#i found one and reposted on my website, download it onto colab:
! wget -q -O nj-counties.zip https://github.com/beryl/GIS_class/raw/main/tl_2022_34_cousub.zip

zip_ref = zipfile.ZipFile('nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
njC=gpd.read_file('tl_2022_34_cousub.shp') #load the shapefile with gpd as njC

# %%
#make the map
njC.plot()
# Out:
# <Axes: >
